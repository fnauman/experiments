# %% [markdown]
# # Whisper using `huggingface`

# %%
from transformers import pipeline

# %%
whisper = pipeline("automatic-speech-recognition", model="openai/whisper-medium", device=0)
# Out:
# (…)/whisper-medium/resolve/main/config.json:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# (…)dium/resolve/main/generation_config.json:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# (…)edium/resolve/main/tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# (…)i/whisper-medium/resolve/main/vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# (…)isper-medium/resolve/main/tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# (…)i/whisper-medium/resolve/main/merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# (…)sper-medium/resolve/main/normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# (…)er-medium/resolve/main/added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# (…)ium/resolve/main/special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# (…)um/resolve/main/preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]

# %%
# !wget -O darkknight_die.mp3 http://www.moviesoundclips.net/movies1/darkknight/die.mp3
# Out:
# --2023-10-18 14:52:49--  http://www.moviesoundclips.net/movies1/darkknight/die.mp3
# Resolving www.moviesoundclips.net (www.moviesoundclips.net)... 198.54.115.219
# Connecting to www.moviesoundclips.net (www.moviesoundclips.net)|198.54.115.219|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57900 (57K) [audio/mpeg]
# Saving to: ‘darkknight_die.mp3’
#
# darkknight_die.mp3  100%[===================>]  56,54K   115KB/s    in 0,5s
#
# 2023-10-18 14:52:50 (115 KB/s) - ‘darkknight_die.mp3’ saved [57900/57900]

# %%
from IPython.display import Audio, display
display(Audio("darkknight_die.mp3", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
whisper("darkknight_die.mp3")
# Out:
# /home/nauman/miniconda3/envs/huggingface/lib/python3.11/site-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (448) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# {'text': " Starting tonight, people will die. I'm a man of my word."}
